# %% [markdown]
# <a href="https://colab.research.google.com/github/ss7673457-eng/1st-update/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a='i am a boy.'
print(type(a))
print(a)
len(a)
# Out:
# <class 'str'>
# i am a boy.
# 11

# %%
b="my name is sahil.\ni am a 22 year old.\ni'm pursuing my skill course"
print(type(b))
print(b)
len(b)
# Out:
# <class 'str'>
# my name is sahil.
# i am a 22 year old.
# i'm pursuing my skill course
# 66

# %%
c= a==b
print(c)
type(c)
# Out:
# False
# bool

# %%
d="i am a boy."
print(type(d))
print(d)
print(d[-8])
len(d)
# Out:
# <class 'str'>
# i am a boy.
# m
# 11

# %%
print(d[0:9])
# Out:
# i am a bo

# %%
print(d[0:11:1])
# Out:
# i am a boy.

# %%
print(d[0:11:2])
# Out:
# ia  o.

# %%
print(d[ : : -1])
# Out:
# .yob a ma i

# %%
print(d[-9:-3])
# Out:
# am a b

# %%
s= "ram"
d="sita"
s+d
# Out:
# 'ramsita'

# %%
h="ding ding"  #h variable is a ding ding
n="chamak challo" #n variable is a chamak challo
print(h*3+"_"+n)
print(type(h))
print(type(n))
# Out:
# ding dingding dingding ding_chamak challo
# <class 'str'>
# <class 'str'>

# %%
a="sahil"
print(type(a))
b=bool(a)
print(type(b))
# Out:
# <class 'str'>
# <class 'bool'>

# %%
a.find("i")
# Out:
# 3

# %%
a.replace("s","m")
# Out:
# 'mahil'

# %%
len(a)
# Out:
# 5

# %%
a.upper()
# Out:
# 'SAHIL'

# %%
a.lower()
# Out:
# 'sahil'

# %%
loss_functions = ['Mean Absolute Error','Mean Squared Error','Huber Loss','Log L0ss','Hinge Loss']
print(loss_functions [3][ 4:8])
# Out:
# L0ss

# %%
s= ["hello",100.90,199,True,"rahul"]
print(s[0][2:7])
# Out:
# llo

# %%
print(s[0].upper())
# Out:
# HELLO

# %%
print(s[0].lower())
# Out:
# hello

# %%
len(s[0])
# Out:
# 5

# %%
min(s[0])
# Out:
# 'e'

# %%
d=["rahul","sahil","abhi","naziya"]
d+["disha"]
print(d)
d=d+["disha"]
print(d)
# Out:
# ['rahul', 'sahil', 'abhi', 'naziya']
# ['rahul', 'sahil', 'abhi', 'naziya', 'disha']

# %%
r=[12,13,13,45,56,434,676,34,57,]
sum(r)
sorted(r)
print(r)
min(r)
max(r)
# Out:
# [12, 13, 13, 45, 56, 434, 676, 34, 57]
# 676

# %%
d=[23,43,3345.3,23,4.4,332,]
d.append([230])
print(d)
# Out:
# [23, 43, 3345.3, 23, 4.4, 332, [230]]

# %%
rajat=("sahil",200,30.98,True,)
print(rajat)
print(type(rajat))
print(rajat[0][2])
# Out:
# ('sahil', 200, 30.98, True)
# <class 'tuple'>
# h

# %%
a={"rajat",349,349,90,48.90,True}
a.add(47)
print(a)
# Out:
# {48.9, True, 90, 349, 'rajat', 47}

# %%
print(a)
# Out:
# {48.9, True, 90, 349, 'rajat', 47}

# %%
a.update(["rajat"],["sahil"])

# %%
print(a)
# Out:
# {48.9, True, 'sahil', 90, 349, 'rajat', 47}

# %%
d={"urvi",32,True,34.00}
b={"sahil",335,23.5,False,32}
print(d & b)
# Out:
# {32}

# %%
s={"Name": "sahil", "age": 22, "hobbies": "playing football",4 :38.545,True: 4345,"b":[234,54232,5.6,"rajat"]}
s.update({"age":367})
print(s)
# Out:
# {'Name': 'sahil', 'age': 367, 'hobbies': 'playing football', 4: 38.545, True: 4345, 'b': [234, 54232, 5.6, 'rajat']}

# %%
 d={1,2,3,}
 c={"sahil","rohan","rehman"}
 f={21,32,45,}
 list(zip(c,d,f))
# Out:
# [('rehman', 1, 32), ('rohan', 2, 21), ('sahil', 3, 45)]

# %%
d=input("Name :     ")
if d== "sahil":
 print("true")
else:
  print("false")
# Out:
# Name :     sahil
# true

# %%
d="python"
d[1:]

# %%
d="tuhar bhadouria"
d= d[-1]+d[1:-1]+s[0]
print(d)

# %%
n= "sahil"
n=n[-1]+n[1:-1]+n[0]
print(n)

# %%
a=input("enter your name :  "  )
# Out:
# enter your name :  sahil

# %%
s=int(input("enter a number: "))
if s%2== 0:
  print("even")
else:
  print("odd")

# %%
d=input("enter a word: ")
if d=="nitin":
  print("valid")
else:
  print("not valid")

# %%
c=input("enter your city: ")
c=c.upper()
if c=="DELHI":
  print("you live in unnion territory")
elif c=="MUMBAI":
  print("you live in film city")
elif c=="BANGLORE":
  print("you live in sillicon valley")
else:
  print("you live in tier 2 city")

# %%
units=float(input("ENTER YOUR ELECTRIC CONSUMPTION: "))
if units<=200:
  print(f"your bills: {0}")
elif units<=250:
   print(f"your bills: {(units-200)*5}")
elif units<=300:
  print(f"your bills : {(250-200)*5+(units-250)*10}")
elif units<=350:
  print(f"your bills: {(250-200)*5+(300-250)*10+(units-300)*15}")
else:
  units>350
  print(f"your bills: {(250-200)*5+(300-250)*10+(350-300)*15+(units-350)*20}")

# %%
pin=int(input("enter your pin "))
if pin==0000:
  action=input("withdraw/statement")
  action=action.lower()
  if action=="withdraw":
    account=input
# Out:
# enter your pin 0000
# withdraw/statementwithdraw

# %%
s=[12,32,56,65,67,347,85,22.45,345,32,12,654,]
n=[]
for d in s:
  n.append(d**2)
print(n)

# %%
s=[12,32,56,65,67,347,85,22.45,345,32,12,654,]
for d in s:
  if d%2==0:
    print(d**2)

  else:
    print(d**3)

# %%
n=["sahil","rajat","stuti","tushar","drishti","earth","kejriwal","nitin"]
for f in n:
  if f.index(f)<=7:
    print(f.upper())
  else:
    f.index(f>=7)
    print(f.lower())
# Out:
# SAHIL
# RAJAT
# STUTI
# TUSHAR
# DRISHTI
# EARTH
# KEJRIWAL
# NITIN
