# %% [markdown]
# <a href="https://colab.research.google.com/github/ss7673457-eng/1st-update/blob/main/Zomato_capstone_project_by_Sahil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ZOMATO CAPSTONE **PROJECT🖥️📊**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("/content/drive/MyDrive/Indian-Resturants.csv")

# %%
df.head(10)
# Out:
#     res_id                            name      establishment  \
# 0  3400299                     Bikanervala    ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2  3401013                   Bhagat Halwai    ['Quick Bites']
# 3  3400290                   Bhagat Halwai    ['Quick Bites']
# 4  3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
# 5  3400275                  Domino's Pizza    ['Quick Bites']
# 6  3400296             Honeydew Restaurant    ['Quick Bites']
# 7  3400368                  Domino's Pizza    ['Quick Bites']
# 8  3401284                      Cake House         ['Bakery']
# 9  3400838                   Sugar N Thyme           ['Café']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# ...

# %%
df.tail(10)
# Out:
#           res_id                            name      establishment  \
# 211934   3200763                            Swad    ['Quick Bites']
# 211935   3201351                    Mummys Pizza  ['Casual Dining']
# 211936   3202169                  Red Dot Nation  ['Casual Dining']
# 211937  18855810             Biryani aur Baatein  ['Casual Dining']
# 211938  18662583                     Wok On Fire  ['Casual Dining']
# 211939   3202251  Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211940   3200996                      Raju Omlet    ['Quick Bites']
# 211941  18984164                The Grand Thakar  ['Casual Dining']
# 211942   3201138                          Subway    ['Quick Bites']
# 211943  18879846     Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# 211934  https://www.zomato.com/vadodara/swad-karelibau...
# 211935  https://www.zomato.com/vadodara/mummys-pizza-d...
# ...

# %%
f"ROWS :{df.shape[0]} COLUMNS : {df.shape[1]}"
# Out:
# 'ROWS :211944 COLUMNS : 26'

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#     res_id                            name      establishment  \
# 0  3400299                     Bikanervala    ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2  3401013                   Bhagat Halwai    ['Quick Bites']
# 3  3400290                   Bhagat Halwai    ['Quick Bites']
# 4  3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211944 entries, 0 to 211943
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   res_id                211944 non-null  int64
#  1   name                  211944 non-null  object
#  2   establishment         211944 non-null  object
#  3   url                   211944 non-null  object
#  4   address               211810 non-null  object
#  5   city                  211944 non-null  object
#  6   city_id               211944 non-null  int64
#  7   locality              211944 non-null  object
#  8   latitude              211944 non-null  float64
#  9   longitude             211944 non-null  float64
#  10  zipcode               48757 non-null   object
#  11  country_id            211944 non-null  int64
#  12  locality_verbose      211944 non-null  object
#  13  cuisines              210553 non-null  object
# ...

# %%
df.describe()
# Out:
#              res_id        city_id       latitude      longitude  country_id  \
# count  2.119440e+05  211944.000000  211944.000000  211944.000000    211944.0
# mean   1.349411e+07    4746.785434      21.499758      77.615276         1.0
# std    7.883722e+06    5568.766386      22.781331       7.500104         0.0
# min    5.000000e+01       1.000000       0.000000       0.000000         1.0
# 25%    3.301027e+06      11.000000      15.496071      74.877961         1.0
# 50%    1.869573e+07      34.000000      22.514494      77.425971         1.0
# 75%    1.881297e+07   11306.000000      26.841667      80.219323         1.0
# max    1.915979e+07   11354.000000   10000.000000      91.832769         1.0
#
#        average_cost_for_two    price_range  aggregate_rating          votes  \
# count         211944.000000  211944.000000     211944.000000  211944.000000
# mean             595.812229       1.882535          3.395937     378.001864
# ...

# %%
list(df.columns)
# Out:
# ['res_id',
#  'name',
#  'establishment',
#  'url',
#  'address',
#  'city',
#  'city_id',
#  'locality',
#  'latitude',
#  'longitude',
#  'zipcode',
#  'country_id',
#  'locality_verbose',
#  'cuisines',
#  'timings',
#  'average_cost_for_two',
#  'price_range',
#  'currency',
#  'highlights',
#  'aggregate_rating',
#  'rating_text',
#  'votes',
#  'photo_count',
#  'opentable_support',
#  'delivery',
#  'takeaway']

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df["name"].value_counts()
# Out:
# name
# Domino's Pizza                         3108
# KFC                                    1343
# Cafe Coffee Day                        1068
# Pizza Hut                               936
# Subway                                  766
#                                        ...
# Bombay Sandwich Bites                     1
# Wah Ustad                                 1
# Bombay Seekh Paratha                      1
# Sam's Burger And Fries                    1
# Tarkari - A Banyan Paradise Kitchen       1
# Name: count, Length: 41100, dtype: int64

# %%
df.isnull().sum()
# Out:
# res_id                       0
# name                         0
# establishment                0
# url                          0
# address                    134
# city                         0
# city_id                      0
# locality                     0
# latitude                     0
# longitude                    0
# zipcode                 163187
# country_id                   0
# locality_verbose             0
# cuisines                  1391
# timings                   3874
# average_cost_for_two         0
# price_range                  0
# currency                     0
# highlights                   0
# aggregate_rating             0
# rating_text                  0
# votes                        0
# photo_count                  0
# opentable_support           48
# delivery                     0
# takeaway                     0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# res_id                   0.000000
# name                     0.000000
# establishment            0.000000
# url                      0.000000
# address                  0.063224
# city                     0.000000
# city_id                  0.000000
# locality                 0.000000
# latitude                 0.000000
# longitude                0.000000
# zipcode                 76.995338
# country_id               0.000000
# locality_verbose         0.000000
# cuisines                 0.656305
# timings                  1.827841
# average_cost_for_two     0.000000
# price_range              0.000000
# currency                 0.000000
# highlights               0.000000
# aggregate_rating         0.000000
# rating_text              0.000000
# votes                    0.000000
# photo_count              0.000000
# opentable_support        0.022647
# delivery                 0.000000
# takeaway                 0.000000
# dtype: float64

# %%
df[df["zipcode"].isnull()]
# Out:
#           res_id                         name      establishment  \
# 0        3400299                  Bikanervala    ['Quick Bites']
# 4        3401744  The Salt Cafe Kitchen & Bar  ['Casual Dining']
# 5        3400275               Domino's Pizza    ['Quick Bites']
# 7        3400368               Domino's Pizza    ['Quick Bites']
# 8        3401284                   Cake House         ['Bakery']
# ...          ...                          ...                ...
# 211937  18855810          Biryani aur Baatein  ['Casual Dining']
# 211938  18662583                  Wok On Fire  ['Casual Dining']
# 211940   3200996                   Raju Omlet    ['Quick Bites']
# 211941  18984164             The Grand Thakar  ['Casual Dining']
# 211942   3201138                       Subway    ['Quick Bites']
#
#                                                       url  \
# 0       https://www.zomato.com/agra/bikanervala-khanda...
# 4       https://www.zomato.com/agra/the-salt-cafe-kitc...
# ...

# %%
df.drop("zipcode",axis=1,inplace=True)
display(df.head())
# Out:
#     res_id                            name      establishment  \
# 0  3400299                     Bikanervala    ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2  3401013                   Bhagat Halwai    ['Quick Bites']
# 3  3400290                   Bhagat Halwai    ['Quick Bites']
# 4  3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# ...

# %%
df[df["timings"].isnull()]
# Out:
#           res_id                             name      establishment  \
# 126      3400957                            Anise    ['Fine Dining']
# 214     19032611    Om Sai Lassi And Juice Corner  ['Beverage Shop']
# 220     19050396                    Agarwal Lassi          ['Shack']
# 297     19031666                    chai ki tapri           ['Café']
# 383      3400322    Filmy Zayka - Hotel Alleviate  ['Casual Dining']
# ...          ...                              ...                ...
# 207778  19065540              Bake N Break Bakery         ['Bakery']
# 208022  19065540              Bake N Break Bakery         ['Bakery']
# 208465  19065540              Bake N Break Bakery         ['Bakery']
# 209415   3200082  Salsa Habanero Mexican Taqueria  ['Casual Dining']
# 210951  18732612       Elysian: The Bistro Lounge  ['Casual Dining']
#
#                                                       url  \
# 126     https://www.zomato.com/agra/anise-tajganj?utm_...
# ...

# %%
df["timings"].mode()
# Out:
# 0    11 AM to 11 PM
# Name: timings, dtype: object

# %%
df["timings"]=df["timings"].fillna(df["timings"].mode()[0])

# %%
df["cuisines"].mode()
# Out:
# 0    North Indian
# Name: cuisines, dtype: object

# %%
df["cuisines"]=df["cuisines"].fillna(df["cuisines"].mode()[0])

# %%
df.isnull().sum()
# Out:
# res_id                    0
# name                      0
# establishment             0
# url                       0
# address                 134
# city                      0
# city_id                   0
# locality                  0
# latitude                  0
# longitude                 0
# country_id                0
# locality_verbose          0
# cuisines                  0
# timings                   0
# average_cost_for_two      0
# price_range               0
# currency                  0
# highlights                0
# aggregate_rating          0
# rating_text               0
# votes                     0
# photo_count               0
# opentable_support        48
# delivery                  0
# takeaway                  0
# dtype: int64

# %%
df['address'].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipython-input-1566901834.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['address'].fillna('Unknown', inplace=True)

# %%
df['address'].isnull().sum()
# Out:
# np.int64(0)

# %%
df["opentable_support"].isnull().sum()
# Out:
# np.int64(48)

# %%
df["opentable_support"].median()
# Out:
# 0.0

# %%
df["opentable_support"]=df["opentable_support"].fillna(df["opentable_support"].median())

# %%
df.duplicated().sum()
# Out:
# np.int64(151533)

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# res_id                  0
# name                    0
# establishment           0
# url                     0
# address                 0
# city                    0
# city_id                 0
# locality                0
# latitude                0
# longitude               0
# country_id              0
# locality_verbose        0
# cuisines                0
# timings                 0
# average_cost_for_two    0
# price_range             0
# currency                0
# highlights              0
# aggregate_rating        0
# rating_text             0
# votes                   0
# photo_count             0
# opentable_support       0
# delivery                0
# takeaway                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df["aggregate_rating"].mean()
# Out:
# np.float64(3.0328632202744537)

# %%
a=df.groupby("name")["aggregate_rating"].mean().head(20)
a
# Out:
# name
# # Wednesday                            3.50
# #1, Culinary Avenue - The Red Maple    3.90
# #788 Avenue                            3.90
# #BC                                    4.20
# #BEiR                                  4.10
# #Dilliwaala6                           4.20
# #Jaipur Darbar                         3.40
# #OFF Campus                            4.00
# #Selfieccino                           3.30
# #Underground Restro & Bar              3.20
# #Waffles                               3.95
# #World of Waffles                      0.00
# #gachKhana                             2.60
# #nofilter                              3.90
# ( SFC )Singh Fresh Chicken             4.00
# -301°F!                                2.70
# .Peg Bar - Radisson Blu Hotel          3.90
# 007 Punjabi Dhaba                      4.30
# 007 Restro Bar - Hotel Seetal          3.30
# 009 Restaurant                         3.50
# Name: aggregate_rating, dtype: float64

# %%
a=df.groupby("name")["aggregate_rating"].mean().head(20)
plt.figure(figsize=(7,7))
sns.swarmplot(y=a.index.astype(str),x=a.values,color="red")
plt.title(" RANDOM 20 RESTAURENTS  AVG RATINGS",fontsize=12)
plt.plot()
# Out:
# []

# %%
res= df.groupby('name')['aggregate_rating'].count().sort_values(ascending=False).reset_index(name="count").head(20)
res
# Out:
#                       name  count
# 0           Domino's Pizza    406
# 1          Cafe Coffee Day    323
# 2                      KFC    261
# 3                   Subway    211
# 4                Keventers    208
# 5           Baskin Robbins    207
# 6               McDonald's    155
# 7                Pizza Hut    150
# 8              Burger King    144
# 9          Barbeque Nation    119
# 10                Monginis    108
# 11                   ibaco    102
# 12      The Chocolate Room     87
# 13  The Belgian Waffle Co.     81
# 14           Frozen Bottle     76
# 15              Lassi Shop     74
# 16                 Giani's     73
# 17         Behrouz Biryani     64
# 18            Kanti Sweets     61
# 19       The London Shakes     58

# %%
res= df.groupby('name')['aggregate_rating'].count().sort_values(ascending=False).reset_index(name="count").head(20)
plt.figure(figsize=(7,7))
sns.barplot(x=res["count"],y=res["name"],color="red")
plt.title("Restaurant Ratings", fontsize=(12))
plt.show()

# %%
top_city=df.groupby("city")["name"].count().reset_index(name="restro counts").sort_values("restro counts", ascending=False).head(20)
print(top_city)
# Out:
#           city  restro counts
# 12     Chennai           2612
# 56      Mumbai           2538
# 8    Bangalore           2365
# 74        Pune           1911
# 66   New Delhi           1847
# 34      Jaipur           1456
# 46     Kolkata           1413
# 1    Ahmedabad           1329
# 48     Lucknow           1290
# 22         Goa           1169
# 59      Nagpur           1102
# 32      Indore           1093
# 44       Kochi           1027
# 13  Coimbatore           1019
# 93    Vadodara           1002
# 85       Surat           1001
# 49    Ludhiana            992
# 9       Bhopal            971
# 0         Agra            892
# 31   Hyderabad            866

# %%
top_city=df.groupby("city")["name"].count().reset_index(name="restro counts").sort_values("restro counts", ascending=False).head(20)

plt.figure(figsize=(7,7))
sns.scatterplot(y=top_city["city"],x=top_city["restro counts"],size=top_city["restro counts"],color="red")

plt.show()

# %%
a=df.groupby(["city"])["aggregate_rating"].count().reset_index(name="Rating counts").sort_values("Rating counts",ascending=False).head(20)
a
# Out:
#           city  Rating counts
# 12     Chennai           2612
# 56      Mumbai           2538
# 8    Bangalore           2365
# 74        Pune           1911
# 66   New Delhi           1847
# 34      Jaipur           1456
# 46     Kolkata           1413
# 1    Ahmedabad           1329
# 48     Lucknow           1290
# 22         Goa           1169
# 59      Nagpur           1102
# 32      Indore           1093
# 44       Kochi           1027
# 13  Coimbatore           1019
# 93    Vadodara           1002
# 85       Surat           1001
# 49    Ludhiana            992
# 9       Bhopal            971
# 0         Agra            892
# 31   Hyderabad            866

# %%
a=df.groupby(["city"])["aggregate_rating"].count().reset_index(name="Rating counts").sort_values("Rating counts",ascending=False).head(20)
plt.figure(figsize=(7,7))
sns.lineplot(x=a["Rating counts"],y=a["city"],marker="o",ms=8,mfc="r",mec="green",linestyle="dashdot")
plt.title("TOP RATINGS RESTAURENTS CITIES", fontsize=(12))
plt.grid(axis="x")
plt.show()

# %%
a=df["cuisines"].value_counts().sort_values(ascending=False).reset_index(name="counts").head(20)
a
# Out:
#                               cuisines  counts
# 0                         North Indian    5057
# 1                            Fast Food    2137
# 2                North Indian, Chinese    1720
# 3                               Bakery    1618
# 4                         South Indian    1598
# 5                          Street Food    1221
# 6                                 Cafe    1180
# 7                               Mithai    1032
# 8                             Desserts     950
# 9                     Bakery, Desserts     872
# 10                           Beverages     839
# 11                         Finger Food     649
# 12                    Pizza, Fast Food     642
# 13                 Mithai, Street Food     635
# 14                             Chinese     633
# 15                 Ice Cream, Desserts     612
# 16                           Ice Cream     576
# 17                   Bakery, Fast Food     484
# 18  North Indian, Chinese, Continental     447
# ...

# %%
a=df["cuisines"].value_counts().sort_values(ascending=False).reset_index(name="counts").head(20)
plt.figure(figsize=(7,7))
sns.scatterplot(y=a["cuisines"],x=a["counts"],size=a["counts"],color="red")
plt.title("MOST POPULAR CUISINES",fontsize=(12))
plt.grid(axis="y",linestyle=":",)
plt.show()

# %%
a=df.groupby("cuisines")["aggregate_rating"].size().reset_index(name="count").head(20)
a
# Out:
#                                              cuisines  count
# 0                                              Afghan      5
# 1                                    Afghan, American      1
# 2   Afghan, Arabian, BBQ, Beverages, Biryani, Maha...      1
# 3             Afghan, Arabian, BBQ, Beverages, Burger      1
# 4                            Afghan, Arabian, Biryani      1
# 5                               Afghan, Arabian, Cafe      1
# 6   Afghan, Asian, BBQ, Chinese, Fast Food, Finger...      1
# 7                             Afghan, Bakery, Chinese      1
# 8   Afghan, Bakery, Desserts, Fast Food, Modern In...      1
# 9                         Afghan, Beverages, Desserts      1
# 10             Afghan, Biryani, Mughlai, North Indian      1
# 11                                    Afghan, Mughlai      1
# 12                      Afghan, Mughlai, North Indian      1
# 13                    Afghan, Mughlai, Rolls, Biryani      1
# ...

# %%
a=df.groupby("cuisines")["aggregate_rating"].size().reset_index(name="count").head(20)
plt.figure(figsize=(8,8))
sns.barplot(data=df.head(20).sort_values("cuisines",ascending=False),y="cuisines",x="aggregate_rating",color="red")
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.barplot(data=df,x="price_range",y="aggregate_rating",color="red")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(data=df,y="average_cost_for_two",x="price_range",color="red")
plt.show()

# %%
a=df.groupby('delivery')['aggregate_rating'].mean().round(1)
a.drop(-1,inplace=True)
a=a.rename(index={0:"Delivery not available",1:"Delivery available"})
a
# Out:
# delivery
# Delivery not available    2.9
# Delivery available        3.5
# Name: aggregate_rating, dtype: float64

# %%
a=df.groupby('delivery')['aggregate_rating'].mean().round(1)
a.drop(-1,inplace=True)
a=a.rename(index={0:"Delivery not available",1:"Delivery available"})


plt.figure(figsize=(7,7))
sns.barplot(x=a.index,y=a.values,color="red")
plt.show()

# %%
a=df.groupby("takeaway")["name"].count()
a=a.rename(index={-1:"Dine in"})
a
# Out:
# takeaway
# Dine in    60411
# Name: name, dtype: int64

# %%
a=df.groupby("takeaway")["name"].count()
a=a.rename(index={-1:"Dine in"})

plt.figure(figsize=(7,7))
sns.barplot(y=a.values, x=a.index,color="red")
plt.title(" Dine-in Counts", fontsize=12)
plt.xlabel("Count")
plt.show()

# %%
a = df["name"].value_counts().reset_index(name="outlet_counts").head(20)
a
# Out:
#                       name  outlet_counts
# 0           Domino's Pizza            406
# 1          Cafe Coffee Day            323
# 2                      KFC            261
# 3                   Subway            211
# 4                Keventers            208
# 5           Baskin Robbins            207
# 6               McDonald's            155
# 7                Pizza Hut            150
# 8              Burger King            144
# 9          Barbeque Nation            119
# 10                Monginis            108
# 11                   ibaco            102
# 12      The Chocolate Room             87
# 13  The Belgian Waffle Co.             81
# 14           Frozen Bottle             76
# 15              Lassi Shop             74
# 16                 Giani's             73
# 17         Behrouz Biryani             64
# 18            Kanti Sweets             61
# 19       The London Shakes             58

# %%
a = df["name"].value_counts().reset_index(name="outlet_counts").head(20)
plt.figure(figsize=(7,7))
sns.barplot(y=a["name"],x=a["outlet_counts"],color="red")
plt.title("TOP 10 RESTAURENTS CHAINS",fontsize=(12))
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.barplot(data=df.head(20).sort_index(ascending=False),x="aggregate_rating",y=a["name"],color="red")
plt.title("TOP RESTAURENTS BY THIER RATINGS")
plt.show()

# %%
df_to_plot = df.head(20)
fig = px.bar(data_frame=df_to_plot, y="highlights")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_to_plot = df.head(20).sort_values("highlights", ascending=True)
fig = px.bar(data_frame=df_to_plot, x="aggregate_rating", y="highlights")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from wordcloud import WordCloud

# Join all the highlights into a single string
highlights_text = " ".join(df['highlights'].astype(str))

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(highlights_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
loc = df['locality'].value_counts().head(15)
loc
# Out:
# locality
# Civil Lines       804
# Model Town        485
# Shastri Nagar     417
# Vijay Nagar       404
# Gomti Nagar       315
# Tirumala          257
# Lashkar           233
# College Road      232
# CIDCO             224
# Bistupur          218
# Bedeswar          211
# Sardarpura        205
# Ana Sagar Lake    197
# MG Road           196
# Kotecha Nagar     195
# Name: count, dtype: int64

# %%
loc = df['locality'].value_counts().head(15)

plt.figure(figsize=(8,5))
sns.barplot(x=loc.values, y=loc.index, color="red")
plt.xlabel("No. of Restaurants")
plt.ylabel("Locality")
plt.title("Top 15 Localities by Number of Restaurants", fontsize=14)
plt.show()

# %%
a=df["rating_text"].value_counts().head(6)
ex=(0.1,0,0,0,0,0)
a
# Out:
# rating_text
# Good         17569
# Average      16779
# Very Good    12714
# Not rated    10158
# Excellent     2063
# Poor           590
# Name: count, dtype: int64

# %%
a=df["rating_text"].value_counts().head(6)

fig=plt.pie(x=a.values,labels=a.index,autopct="%1.1f%%",startangle=20,explode=ex)
plt.title("Distribution of Rating Categories")
plt.show()
